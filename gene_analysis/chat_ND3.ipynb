# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
mutation_data = pd.read_csv('full_mutation_data.csv')

# %%
mutation_data
# Out:
#       Unnamed: 0   Patient gene           gene_variant   loci ref alt  \
# 0              0  MF362760  ND1  upstream_gene_variant    152   T   C
# 1              1  MF362760  ND1  upstream_gene_variant    186   C   A
# 2              2  MF362760  ND1  upstream_gene_variant    263   A   G
# 3              3  MF362760  ND1  upstream_gene_variant    750   A   G
# 4              4  MF362760  ND1  upstream_gene_variant   1438   A   G
# ...          ...       ...  ...                    ...    ...  ..  ..
# 2676        2676  KF540700  ND6  upstream_gene_variant  16223   C   T
# 2677        2677  KF540700  ND6  upstream_gene_variant  16242   C   T
# 2678        2678  KF540700  ND6  upstream_gene_variant  16249   T   C
# 2679        2679  KF540700  ND6  upstream_gene_variant  16319   G   A
# 2680        2680  KF540700  ND6  upstream_gene_variant  16519   T   C
#
#            gene_type mutation_nucleotide mutation_aminoacide
# 0     protein_coding          c.-3155T>C                 NaN
# 1     protein_coding          c.-3121C>A                 NaN
# 2     protein_coding          c.-3044A>G                 NaN
# 3     protein_coding          c.-2557A>G                 NaN
# 4     protein_coding          c.-1869A>G                 NaN
# ...              ...                 ...                 ...
# 2676  protein_coding          c.-1550G>A                 NaN
# 2677  protein_coding          c.-1569G>A                 NaN
# 2678  protein_coding          c.-1576A>G                 NaN
# 2679  protein_coding          c.-1646C>T                 NaN
# 2680  protein_coding          c.-1846A>G                 NaN
#
# [2681 rows x 10 columns]

# %%
# Filtering the dataset based on the patient origin (Chinese and Armenian)
chinese_patients = mutation_data[mutation_data['Patient'].str.startswith('KF')]
armenian_patients = mutation_data[mutation_data['Patient'].str.startswith('MF')]


# Number of unique mutations
unique_mutations_chinese = chinese_patients.drop_duplicates(subset=['gene', 'loci', 'ref', 'alt']).shape[0]
unique_mutations_armenian = armenian_patients.drop_duplicates(subset=['gene', 'loci', 'ref', 'alt']).shape[0]

(unique_mutations_chinese, unique_mutations_armenian)
# Out:
# (384, 337)

# %%
# Filtering the dataset for mutations in the ND3 gene for both Chinese and Armenian populations
nd3_chinese = chinese_patients[chinese_patients['gene'] == 'ND3']
nd3_armenian = armenian_patients[armenian_patients['gene'] == 'ND3']

# Analyzing ND3 mutations
# 1. Number of unique mutations in ND3 for each population
# 2. Distribution of ND3 mutations across loci
# 3. Types of ND3 gene variants

# Number of unique mutations in ND3
unique_nd3_mutations_chinese = nd3_chinese.drop_duplicates(subset=['loci', 'ref', 'alt']).shape[0]
unique_nd3_mutations_armenian = nd3_armenian.drop_duplicates(subset=['loci', 'ref', 'alt']).shape[0]

(unique_nd3_mutations_chinese, unique_nd3_mutations_armenian)
# Out:
# (10, 7)

# %%
# Filtering the dataset for synonymous and non-synonymous mutations in the ND3 gene
nd3_chinese_synonymous = nd3_chinese[nd3_chinese['gene_variant'] == 'synonymous_variant']
nd3_chinese_missense = nd3_chinese[nd3_chinese['gene_variant'] == 'missense_variant']
nd3_armenian_synonymous = nd3_armenian[nd3_armenian['gene_variant'] == 'synonymous_variant']
nd3_armenian_missense = nd3_armenian[nd3_armenian['gene_variant'] == 'missense_variant']

# Counting the number of synonymous (dS) and non-synonymous (dN) mutations in each population
chinese_dS = nd3_chinese_synonymous.shape[0]
chinese_dN = nd3_chinese_missense.shape[0]
armenian_dS = nd3_armenian_synonymous.shape[0]
armenian_dN = nd3_armenian_missense.shape[0]

# Calculating the dN/dS ratio for each population
# Avoid division by zero by adding a small number (epsilon) to the denominator
epsilon = 1e-6
chinese_dN_dS_ratio = chinese_dN / (chinese_dS + epsilon)
armenian_dN_dS_ratio = armenian_dN / (armenian_dS + epsilon)

(chinese_dN_dS_ratio, armenian_dN_dS_ratio, chinese_dN, chinese_dS, armenian_dN, armenian_dS)
# Out:
# (0.8124999746093758, 0.7999999200000081, 26, 32, 8, 10)

# %%
nd3_armenian
# Out:
#       Unnamed: 0   Patient gene           gene_variant   loci ref alt  \
# 95            95  MF362763  ND3       missense_variant  10398   A   G
# 178          178  MF362766  ND3  upstream_gene_variant  10034   T   C
# 179          179  MF362766  ND3     synonymous_variant  10238   T   C
# 180          180  MF362766  ND3       missense_variant  10398   A   G
# 309          309  MF362770  ND3     synonymous_variant  10238   T   C
# 385          385  MF362772  ND3     synonymous_variant  10142   C   T
# 419          419  MF362773  ND3     synonymous_variant  10293   C   T
# 420          420  MF362773  ND3       missense_variant  10398   A   G
# 459          459  MF362774  ND3     synonymous_variant  10238   T   C
# 557          557  MF362778  ND3     synonymous_variant  10289   A   G
# 558          558  MF362778  ND3       missense_variant  10398   A   G
# 680          680  MF362782  ND3     synonymous_variant  10142   C   T
# 715          715  MF362783  ND3       missense_variant  10398   A   G
# 825          825  MF362788  ND3       missense_variant  10398   A   G
# 864          864  MF362789  ND3       missense_variant  10398   A   G
# 1010        1010  MF362794  ND3     synonymous_variant  10238   T   C
# 1159        1159  MF362801  ND3       missense_variant  10398   A   G
# 1182        1182  MF362802  ND3     synonymous_variant  10217   A   G
# 1209        1209  MF362804  ND3     synonymous_variant  10217   A   G
#
#            gene_type mutation_nucleotide mutation_aminoacide
# 95    protein_coding            c.340A>G         p.Thr114Ala
# 178   protein_coding            c.-25T>C                 NaN
# 179   protein_coding            c.180T>C          p.Ile60Ile
# 180   protein_coding            c.340A>G         p.Thr114Ala
# 309   protein_coding            c.180T>C          p.Ile60Ile
# 385   protein_coding             c.84C>T          p.Asn28Asn
# 419   protein_coding            c.235C>T          p.Leu79Leu
# 420   protein_coding            c.340A>G         p.Thr114Ala
# 459   protein_coding            c.180T>C          p.Ile60Ile
# 557   protein_coding            c.231A>G          p.Trp77Trp
# 558   protein_coding            c.340A>G         p.Thr114Ala
# 680   protein_coding             c.84C>T          p.Asn28Asn
# 715   protein_coding            c.340A>G         p.Thr114Ala
# 825   protein_coding            c.340A>G         p.Thr114Ala
# 864   protein_coding            c.340A>G         p.Thr114Ala
# 1010  protein_coding            c.180T>C          p.Ile60Ile
# 1159  protein_coding            c.340A>G         p.Thr114Ala
# 1182  protein_coding            c.159A>G          p.Met53Met
# 1209  protein_coding            c.159A>G          p.Met53Met

# %%
nd3_armenian_synonymous
# Out:
#       Unnamed: 0   Patient gene        gene_variant   loci ref alt  \
# 179          179  MF362766  ND3  synonymous_variant  10238   T   C
# 309          309  MF362770  ND3  synonymous_variant  10238   T   C
# 385          385  MF362772  ND3  synonymous_variant  10142   C   T
# 419          419  MF362773  ND3  synonymous_variant  10293   C   T
# 459          459  MF362774  ND3  synonymous_variant  10238   T   C
# 557          557  MF362778  ND3  synonymous_variant  10289   A   G
# 680          680  MF362782  ND3  synonymous_variant  10142   C   T
# 1010        1010  MF362794  ND3  synonymous_variant  10238   T   C
# 1182        1182  MF362802  ND3  synonymous_variant  10217   A   G
# 1209        1209  MF362804  ND3  synonymous_variant  10217   A   G
#
#            gene_type mutation_nucleotide mutation_aminoacide
# 179   protein_coding            c.180T>C          p.Ile60Ile
# 309   protein_coding            c.180T>C          p.Ile60Ile
# 385   protein_coding             c.84C>T          p.Asn28Asn
# 419   protein_coding            c.235C>T          p.Leu79Leu
# 459   protein_coding            c.180T>C          p.Ile60Ile
# 557   protein_coding            c.231A>G          p.Trp77Trp
# 680   protein_coding             c.84C>T          p.Asn28Asn
# 1010  protein_coding            c.180T>C          p.Ile60Ile
# 1182  protein_coding            c.159A>G          p.Met53Met
# 1209  protein_coding            c.159A>G          p.Met53Met

# %%
nd3_armenian_missense
# Out:
#       Unnamed: 0   Patient gene      gene_variant   loci ref alt  \
# 95            95  MF362763  ND3  missense_variant  10398   A   G
# 180          180  MF362766  ND3  missense_variant  10398   A   G
# 420          420  MF362773  ND3  missense_variant  10398   A   G
# 558          558  MF362778  ND3  missense_variant  10398   A   G
# 715          715  MF362783  ND3  missense_variant  10398   A   G
# 825          825  MF362788  ND3  missense_variant  10398   A   G
# 864          864  MF362789  ND3  missense_variant  10398   A   G
# 1159        1159  MF362801  ND3  missense_variant  10398   A   G
#
#            gene_type mutation_nucleotide mutation_aminoacide
# 95    protein_coding            c.340A>G         p.Thr114Ala
# 180   protein_coding            c.340A>G         p.Thr114Ala
# 420   protein_coding            c.340A>G         p.Thr114Ala
# 558   protein_coding            c.340A>G         p.Thr114Ala
# 715   protein_coding            c.340A>G         p.Thr114Ala
# 825   protein_coding            c.340A>G         p.Thr114Ala
# 864   protein_coding            c.340A>G         p.Thr114Ala
# 1159  protein_coding            c.340A>G         p.Thr114Ala

# %%
nd3_chinese_synonymous
# Out:
#       Unnamed: 0   Patient gene        gene_variant   loci ref alt  \
# 1237        1237  KF540656  ND3  synonymous_variant  10400   C   T
# 1280        1280  KF540657  ND3  synonymous_variant  10400   C   T
# 1310        1310  KF540658  ND3  synonymous_variant  10310   G   A
# 1369        1369  KF540660  ND3  synonymous_variant  10238   T   C
# 1459        1459  KF540663  ND3  synonymous_variant  10400   C   T
# 1495        1495  KF540664  ND3  synonymous_variant  10400   C   T
# 1584        1584  KF540667  ND3  synonymous_variant  10400   C   T
# 1614        1614  KF540668  ND3  synonymous_variant  10325   G   A
# 1649        1649  KF540669  ND3  synonymous_variant  10400   C   T
# 1686        1686  KF540670  ND3  synonymous_variant  10400   C   T
# 1747        1747  KF540672  ND3  synonymous_variant  10400   C   T
# 1781        1781  KF540673  ND3  synonymous_variant  10238   T   C
# 1809        1809  KF540674  ND3  synonymous_variant  10397   A   G
# 1811        1811  KF540674  ND3  synonymous_variant  10400   C   T
# 1901        1901  KF540677  ND3  synonymous_variant  10400   C   T
# 1993        1993  KF540680  ND3  synonymous_variant  10101   T   C
# 1995        1995  KF540680  ND3  synonymous_variant  10400   C   T
# 2030        2030  KF540681  ND3  synonymous_variant  10370   T   C
# 2032        2032  KF540681  ND3  synonymous_variant  10400   C   T
# 2096        2096  KF540683  ND3  synonymous_variant  10400   C   T
# 2157        2157  KF540685  ND3  synonymous_variant  10238   T   C
# 2189        2189  KF540686  ND3  synonymous_variant  10400   C   T
# 2229        2229  KF540687  ND3  synonymous_variant  10400   C   T
# 2263        2263  KF540688  ND3  synonymous_variant  10238   T   C
# 2376        2376  KF540692  ND3  synonymous_variant  10289   A   G
# 2378        2378  KF540692  ND3  synonymous_variant  10400   C   T
# 2423        2423  KF540693  ND3  synonymous_variant  10400   C   T
# 2495        2495  KF540695  ND3  synonymous_variant  10310   G   A
# 2533        2533  KF540696  ND3  synonymous_variant  10400   C   T
# 2572        2572  KF540697  ND3  synonymous_variant  10400   C   T
# 2607        2607  KF540698  ND3  synonymous_variant  10310   G   A
# 2663        2663  KF540700  ND3  synonymous_variant  10400   C   T
#
#            gene_type mutation_nucleotide mutation_aminoacide
# 1237  protein_coding            c.342C>T         p.Thr114Thr
# 1280  protein_coding            c.342C>T         p.Thr114Thr
# 1310  protein_coding            c.252G>A          p.Leu84Leu
# 1369  protein_coding            c.180T>C          p.Ile60Ile
# 1459  protein_coding            c.342C>T         p.Thr114Thr
# 1495  protein_coding            c.342C>T         p.Thr114Thr
# 1584  protein_coding            c.342C>T         p.Thr114Thr
# 1614  protein_coding            c.267G>A          p.Met89Met
# 1649  protein_coding            c.342C>T         p.Thr114Thr
# 1686  protein_coding            c.342C>T         p.Thr114Thr
# 1747  protein_coding            c.342C>T         p.Thr114Thr
# 1781  protein_coding            c.180T>C          p.Ile60Ile
# 1809  protein_coding            c.339A>G         p.Trp113Trp
# 1811  protein_coding            c.342C>T         p.Thr114Thr
# 1901  protein_coding            c.342C>T         p.Thr114Thr
# 1993  protein_coding             c.43T>C          p.Leu15Leu
# 1995  protein_coding            c.342C>T         p.Thr114Thr
# 2030  protein_coding            c.312T>C         p.Tyr104Tyr
# 2032  protein_coding            c.342C>T         p.Thr114Thr
# 2096  protein_coding            c.342C>T         p.Thr114Thr
# 2157  protein_coding            c.180T>C          p.Ile60Ile
# 2189  protein_coding            c.342C>T         p.Thr114Thr
# 2229  protein_coding            c.342C>T         p.Thr114Thr
# 2263  protein_coding            c.180T>C          p.Ile60Ile
# 2376  protein_coding            c.231A>G          p.Trp77Trp
# 2378  protein_coding            c.342C>T         p.Thr114Thr
# 2423  protein_coding            c.342C>T         p.Thr114Thr
# 2495  protein_coding            c.252G>A          p.Leu84Leu
# 2533  protein_coding            c.342C>T         p.Thr114Thr
# 2572  protein_coding            c.342C>T         p.Thr114Thr
# 2607  protein_coding            c.252G>A          p.Leu84Leu
# 2663  protein_coding            c.342C>T         p.Thr114Thr

# %%
nd3_chinese_missense
# Out:
#       Unnamed: 0   Patient gene      gene_variant   loci ref alt  \
# 1236        1236  KF540656  ND3  missense_variant  10398   A   G
# 1279        1279  KF540657  ND3  missense_variant  10398   A   G
# 1458        1458  KF540663  ND3  missense_variant  10398   A   G
# 1494        1494  KF540664  ND3  missense_variant  10398   A   G
# 1583        1583  KF540667  ND3  missense_variant  10398   A   G
# 1615        1615  KF540668  ND3  missense_variant  10398   A   G
# 1648        1648  KF540669  ND3  missense_variant  10398   A   G
# 1685        1685  KF540670  ND3  missense_variant  10398   A   G
# 1746        1746  KF540672  ND3  missense_variant  10398   A   G
# 1810        1810  KF540674  ND3  missense_variant  10398   A   G
# 1870        1870  KF540676  ND3  missense_variant  10398   A   G
# 1900        1900  KF540677  ND3  missense_variant  10398   A   G
# 1932        1932  KF540678  ND3  missense_variant  10398   A   G
# 1994        1994  KF540680  ND3  missense_variant  10398   A   G
# 2031        2031  KF540681  ND3  missense_variant  10398   A   G
# 2095        2095  KF540683  ND3  missense_variant  10398   A   G
# 2188        2188  KF540686  ND3  missense_variant  10398   A   G
# 2228        2228  KF540687  ND3  missense_variant  10398   A   G
# 2340        2340  KF540691  ND3  missense_variant  10398   A   G
# 2377        2377  KF540692  ND3  missense_variant  10398   A   G
# 2422        2422  KF540693  ND3  missense_variant  10398   A   G
# 2461        2461  KF540694  ND3  missense_variant  10398   A   G
# 2532        2532  KF540696  ND3  missense_variant  10398   A   G
# 2571        2571  KF540697  ND3  missense_variant  10398   A   G
# 2608        2608  KF540698  ND3  missense_variant  10320   G   A
# 2662        2662  KF540700  ND3  missense_variant  10398   A   G
#
#            gene_type mutation_nucleotide mutation_aminoacide
# 1236  protein_coding            c.340A>G         p.Thr114Ala
# 1279  protein_coding            c.340A>G         p.Thr114Ala
# 1458  protein_coding            c.340A>G         p.Thr114Ala
# 1494  protein_coding            c.340A>G         p.Thr114Ala
# 1583  protein_coding            c.340A>G         p.Thr114Ala
# 1615  protein_coding            c.340A>G         p.Thr114Ala
# 1648  protein_coding            c.340A>G         p.Thr114Ala
# 1685  protein_coding            c.340A>G         p.Thr114Ala
# 1746  protein_coding            c.340A>G         p.Thr114Ala
# 1810  protein_coding            c.340A>G         p.Thr114Ala
# 1870  protein_coding            c.340A>G         p.Thr114Ala
# 1900  protein_coding            c.340A>G         p.Thr114Ala
# 1932  protein_coding            c.340A>G         p.Thr114Ala
# 1994  protein_coding            c.340A>G         p.Thr114Ala
# 2031  protein_coding            c.340A>G         p.Thr114Ala
# 2095  protein_coding            c.340A>G         p.Thr114Ala
# 2188  protein_coding            c.340A>G         p.Thr114Ala
# 2228  protein_coding            c.340A>G         p.Thr114Ala
# 2340  protein_coding            c.340A>G         p.Thr114Ala
# 2377  protein_coding            c.340A>G         p.Thr114Ala
# 2422  protein_coding            c.340A>G         p.Thr114Ala
# 2461  protein_coding            c.340A>G         p.Thr114Ala
# 2532  protein_coding            c.340A>G         p.Thr114Ala
# 2571  protein_coding            c.340A>G         p.Thr114Ala
# 2608  protein_coding            c.262G>A          p.Val88Ile
# 2662  protein_coding            c.340A>G         p.Thr114Ala

# %%
common_nd3_armenian_cols = nd3_armenian['mutation_nucleotide'].isin(nd3_chinese['mutation_nucleotide'])
common_nd3_armenian_cols
common_nd3_armenian = nd3_armenian.loc[common_nd3_armenian_cols, :]
common_nd3_armenian
# Out:
#       Unnamed: 0   Patient gene        gene_variant   loci ref alt  \
# 95            95  MF362763  ND3    missense_variant  10398   A   G
# 179          179  MF362766  ND3  synonymous_variant  10238   T   C
# 180          180  MF362766  ND3    missense_variant  10398   A   G
# 309          309  MF362770  ND3  synonymous_variant  10238   T   C
# 420          420  MF362773  ND3    missense_variant  10398   A   G
# 459          459  MF362774  ND3  synonymous_variant  10238   T   C
# 557          557  MF362778  ND3  synonymous_variant  10289   A   G
# 558          558  MF362778  ND3    missense_variant  10398   A   G
# 715          715  MF362783  ND3    missense_variant  10398   A   G
# 825          825  MF362788  ND3    missense_variant  10398   A   G
# 864          864  MF362789  ND3    missense_variant  10398   A   G
# 1010        1010  MF362794  ND3  synonymous_variant  10238   T   C
# 1159        1159  MF362801  ND3    missense_variant  10398   A   G
#
#            gene_type mutation_nucleotide mutation_aminoacide
# 95    protein_coding            c.340A>G         p.Thr114Ala
# 179   protein_coding            c.180T>C          p.Ile60Ile
# 180   protein_coding            c.340A>G         p.Thr114Ala
# 309   protein_coding            c.180T>C          p.Ile60Ile
# 420   protein_coding            c.340A>G         p.Thr114Ala
# 459   protein_coding            c.180T>C          p.Ile60Ile
# 557   protein_coding            c.231A>G          p.Trp77Trp
# 558   protein_coding            c.340A>G         p.Thr114Ala
# 715   protein_coding            c.340A>G         p.Thr114Ala
# 825   protein_coding            c.340A>G         p.Thr114Ala
# 864   protein_coding            c.340A>G         p.Thr114Ala
# 1010  protein_coding            c.180T>C          p.Ile60Ile
# 1159  protein_coding            c.340A>G         p.Thr114Ala

# %%
common_nd3_chinese_cols = nd3_chinese['mutation_nucleotide'].isin(nd3_armenian['mutation_nucleotide'])
common_nd3_chinese_cols
common_nd3_chinese = nd3_chinese.loc[common_nd3_chinese_cols, :]
common_nd3_chinese
# Out:
#       Unnamed: 0   Patient gene        gene_variant   loci ref alt  \
# 1236        1236  KF540656  ND3    missense_variant  10398   A   G
# 1279        1279  KF540657  ND3    missense_variant  10398   A   G
# 1369        1369  KF540660  ND3  synonymous_variant  10238   T   C
# 1458        1458  KF540663  ND3    missense_variant  10398   A   G
# 1494        1494  KF540664  ND3    missense_variant  10398   A   G
# 1583        1583  KF540667  ND3    missense_variant  10398   A   G
# 1615        1615  KF540668  ND3    missense_variant  10398   A   G
# 1648        1648  KF540669  ND3    missense_variant  10398   A   G
# 1685        1685  KF540670  ND3    missense_variant  10398   A   G
# 1746        1746  KF540672  ND3    missense_variant  10398   A   G
# 1781        1781  KF540673  ND3  synonymous_variant  10238   T   C
# 1810        1810  KF540674  ND3    missense_variant  10398   A   G
# 1870        1870  KF540676  ND3    missense_variant  10398   A   G
# 1900        1900  KF540677  ND3    missense_variant  10398   A   G
# 1932        1932  KF540678  ND3    missense_variant  10398   A   G
# 1994        1994  KF540680  ND3    missense_variant  10398   A   G
# 2031        2031  KF540681  ND3    missense_variant  10398   A   G
# 2095        2095  KF540683  ND3    missense_variant  10398   A   G
# 2157        2157  KF540685  ND3  synonymous_variant  10238   T   C
# 2188        2188  KF540686  ND3    missense_variant  10398   A   G
# 2228        2228  KF540687  ND3    missense_variant  10398   A   G
# 2263        2263  KF540688  ND3  synonymous_variant  10238   T   C
# 2340        2340  KF540691  ND3    missense_variant  10398   A   G
# 2376        2376  KF540692  ND3  synonymous_variant  10289   A   G
# 2377        2377  KF540692  ND3    missense_variant  10398   A   G
# 2422        2422  KF540693  ND3    missense_variant  10398   A   G
# 2461        2461  KF540694  ND3    missense_variant  10398   A   G
# 2532        2532  KF540696  ND3    missense_variant  10398   A   G
# 2571        2571  KF540697  ND3    missense_variant  10398   A   G
# 2662        2662  KF540700  ND3    missense_variant  10398   A   G
#
#            gene_type mutation_nucleotide mutation_aminoacide
# 1236  protein_coding            c.340A>G         p.Thr114Ala
# 1279  protein_coding            c.340A>G         p.Thr114Ala
# 1369  protein_coding            c.180T>C          p.Ile60Ile
# 1458  protein_coding            c.340A>G         p.Thr114Ala
# 1494  protein_coding            c.340A>G         p.Thr114Ala
# 1583  protein_coding            c.340A>G         p.Thr114Ala
# 1615  protein_coding            c.340A>G         p.Thr114Ala
# 1648  protein_coding            c.340A>G         p.Thr114Ala
# 1685  protein_coding            c.340A>G         p.Thr114Ala
# 1746  protein_coding            c.340A>G         p.Thr114Ala
# 1781  protein_coding            c.180T>C          p.Ile60Ile
# 1810  protein_coding            c.340A>G         p.Thr114Ala
# 1870  protein_coding            c.340A>G         p.Thr114Ala
# 1900  protein_coding            c.340A>G         p.Thr114Ala
# 1932  protein_coding            c.340A>G         p.Thr114Ala
# 1994  protein_coding            c.340A>G         p.Thr114Ala
# 2031  protein_coding            c.340A>G         p.Thr114Ala
# 2095  protein_coding            c.340A>G         p.Thr114Ala
# 2157  protein_coding            c.180T>C          p.Ile60Ile
# 2188  protein_coding            c.340A>G         p.Thr114Ala
# 2228  protein_coding            c.340A>G         p.Thr114Ala
# 2263  protein_coding            c.180T>C          p.Ile60Ile
# 2340  protein_coding            c.340A>G         p.Thr114Ala
# 2376  protein_coding            c.231A>G          p.Trp77Trp
# 2377  protein_coding            c.340A>G         p.Thr114Ala
# 2422  protein_coding            c.340A>G         p.Thr114Ala
# 2461  protein_coding            c.340A>G         p.Thr114Ala
# 2532  protein_coding            c.340A>G         p.Thr114Ala
# 2571  protein_coding            c.340A>G         p.Thr114Ala
# 2662  protein_coding            c.340A>G         p.Thr114Ala

# %%
# Filtering the dataset for synonymous and non-synonymous mutations in the ND3 gene
common_nd3_chinese_synonymous = common_nd3_chinese[common_nd3_chinese['gene_variant'] == 'synonymous_variant']
common_nd3_chinese_missense = common_nd3_chinese[common_nd3_chinese['gene_variant'] == 'missense_variant']
common_nd3_armenian_synonymous = common_nd3_armenian[common_nd3_armenian['gene_variant'] == 'synonymous_variant']
common_nd3_armenian_missense = common_nd3_armenian[common_nd3_armenian['gene_variant'] == 'missense_variant']

# Counting the number of synonymous (dS) and non-synonymous (dN) mutations in each population
common_chinese_dS = common_nd3_chinese_synonymous.shape[0]
common_chinese_dN = common_nd3_chinese_missense.shape[0]
common_armenian_dS = common_nd3_armenian_synonymous.shape[0]
common_armenian_dN = common_nd3_armenian_missense.shape[0]

# Calculating the dN/dS ratio for each population
# Avoid division by zero by adding a small number (epsilon) to the denominator
epsilon = 1e-6
common_chinese_dN_dS_ratio = common_chinese_dN / (common_chinese_dS + epsilon)
common_armenian_dN_dS_ratio = common_armenian_dN / (common_armenian_dS + epsilon)

(common_chinese_dN_dS_ratio, common_armenian_dN_dS_ratio, common_chinese_dN, common_chinese_dS, common_armenian_dN, common_armenian_dS)
# Out:
# (4.9999990000002, 1.599999680000064, 25, 5, 8, 5)

# %%
# Out:
#       Unnamed: 0   Patient gene        gene_variant   loci ref alt  \
# 95            95  MF362763  ND3    missense_variant  10398   A   G
# 179          179  MF362766  ND3  synonymous_variant  10238   T   C
# 180          180  MF362766  ND3    missense_variant  10398   A   G
# 309          309  MF362770  ND3  synonymous_variant  10238   T   C
# 420          420  MF362773  ND3    missense_variant  10398   A   G
# 459          459  MF362774  ND3  synonymous_variant  10238   T   C
# 557          557  MF362778  ND3  synonymous_variant  10289   A   G
# 558          558  MF362778  ND3    missense_variant  10398   A   G
# 715          715  MF362783  ND3    missense_variant  10398   A   G
# 825          825  MF362788  ND3    missense_variant  10398   A   G
# 864          864  MF362789  ND3    missense_variant  10398   A   G
# 1010        1010  MF362794  ND3  synonymous_variant  10238   T   C
# 1159        1159  MF362801  ND3    missense_variant  10398   A   G
#
#            gene_type mutation_nucleotide mutation_aminoacide
# 95    protein_coding            c.340A>G         p.Thr114Ala
# 179   protein_coding            c.180T>C          p.Ile60Ile
# 180   protein_coding            c.340A>G         p.Thr114Ala
# 309   protein_coding            c.180T>C          p.Ile60Ile
# 420   protein_coding            c.340A>G         p.Thr114Ala
# 459   protein_coding            c.180T>C          p.Ile60Ile
# 557   protein_coding            c.231A>G          p.Trp77Trp
# 558   protein_coding            c.340A>G         p.Thr114Ala
# 715   protein_coding            c.340A>G         p.Thr114Ala
# 825   protein_coding            c.340A>G         p.Thr114Ala
# 864   protein_coding            c.340A>G         p.Thr114Ala
# 1010  protein_coding            c.180T>C          p.Ile60Ile
# 1159  protein_coding            c.340A>G         p.Thr114Ala

# %%
# Create a boolean mask to identify common rows in nd3_armenian
mask = nd3_armenian[['gene', 'gene_variant', 'loci', 'ref', 'alt', 'gene_type', 'mutation_nucleotide', 'mutation_aminoacide']].isin(common_nd3_armenian[['gene', 'gene_variant', 'loci', 'ref', 'alt', 'gene_type', 'mutation_nucleotide', 'mutation_aminoacide']]).all(axis=1)

# Invert the mask to select rows that are not common
nd3_armenian_unique = nd3_armenian[~mask]

# Display the DataFrame with unique mutations for nd3_armenian
nd3_armenian_unique
# Out:
#       Unnamed: 0   Patient gene           gene_variant   loci ref alt  \
# 178          178  MF362766  ND3  upstream_gene_variant  10034   T   C
# 385          385  MF362772  ND3     synonymous_variant  10142   C   T
# 419          419  MF362773  ND3     synonymous_variant  10293   C   T
# 680          680  MF362782  ND3     synonymous_variant  10142   C   T
# 1182        1182  MF362802  ND3     synonymous_variant  10217   A   G
# 1209        1209  MF362804  ND3     synonymous_variant  10217   A   G
#
#            gene_type mutation_nucleotide mutation_aminoacide
# 178   protein_coding            c.-25T>C                 NaN
# 385   protein_coding             c.84C>T          p.Asn28Asn
# 419   protein_coding            c.235C>T          p.Leu79Leu
# 680   protein_coding             c.84C>T          p.Asn28Asn
# 1182  protein_coding            c.159A>G          p.Met53Met
# 1209  protein_coding            c.159A>G          p.Met53Met

# %%
# Create a boolean mask to identify common rows in nd3_armenian
mask = nd3_chinese[['gene', 'gene_variant', 'loci', 'ref', 'alt', 'gene_type', 'mutation_nucleotide', 'mutation_aminoacide']].isin(common_nd3_chinese[['gene', 'gene_variant', 'loci', 'ref', 'alt', 'gene_type', 'mutation_nucleotide', 'mutation_aminoacide']]).all(axis=1)

# Invert the mask to select rows that are not common
nd3_chinese_unique = nd3_chinese[~mask]

# Display the DataFrame with unique mutations for nd3_armenian
nd3_chinese_unique
# Out:
#       Unnamed: 0   Patient gene        gene_variant   loci ref alt  \
# 1237        1237  KF540656  ND3  synonymous_variant  10400   C   T
# 1280        1280  KF540657  ND3  synonymous_variant  10400   C   T
# 1310        1310  KF540658  ND3  synonymous_variant  10310   G   A
# 1459        1459  KF540663  ND3  synonymous_variant  10400   C   T
# 1495        1495  KF540664  ND3  synonymous_variant  10400   C   T
# 1584        1584  KF540667  ND3  synonymous_variant  10400   C   T
# 1614        1614  KF540668  ND3  synonymous_variant  10325   G   A
# 1649        1649  KF540669  ND3  synonymous_variant  10400   C   T
# 1686        1686  KF540670  ND3  synonymous_variant  10400   C   T
# 1747        1747  KF540672  ND3  synonymous_variant  10400   C   T
# 1809        1809  KF540674  ND3  synonymous_variant  10397   A   G
# 1811        1811  KF540674  ND3  synonymous_variant  10400   C   T
# 1901        1901  KF540677  ND3  synonymous_variant  10400   C   T
# 1993        1993  KF540680  ND3  synonymous_variant  10101   T   C
# 1995        1995  KF540680  ND3  synonymous_variant  10400   C   T
# 2030        2030  KF540681  ND3  synonymous_variant  10370   T   C
# 2032        2032  KF540681  ND3  synonymous_variant  10400   C   T
# 2096        2096  KF540683  ND3  synonymous_variant  10400   C   T
# 2189        2189  KF540686  ND3  synonymous_variant  10400   C   T
# 2229        2229  KF540687  ND3  synonymous_variant  10400   C   T
# 2378        2378  KF540692  ND3  synonymous_variant  10400   C   T
# 2423        2423  KF540693  ND3  synonymous_variant  10400   C   T
# 2495        2495  KF540695  ND3  synonymous_variant  10310   G   A
# 2533        2533  KF540696  ND3  synonymous_variant  10400   C   T
# 2572        2572  KF540697  ND3  synonymous_variant  10400   C   T
# 2607        2607  KF540698  ND3  synonymous_variant  10310   G   A
# 2608        2608  KF540698  ND3    missense_variant  10320   G   A
# 2663        2663  KF540700  ND3  synonymous_variant  10400   C   T
#
#            gene_type mutation_nucleotide mutation_aminoacide
# 1237  protein_coding            c.342C>T         p.Thr114Thr
# 1280  protein_coding            c.342C>T         p.Thr114Thr
# 1310  protein_coding            c.252G>A          p.Leu84Leu
# 1459  protein_coding            c.342C>T         p.Thr114Thr
# 1495  protein_coding            c.342C>T         p.Thr114Thr
# 1584  protein_coding            c.342C>T         p.Thr114Thr
# 1614  protein_coding            c.267G>A          p.Met89Met
# 1649  protein_coding            c.342C>T         p.Thr114Thr
# 1686  protein_coding            c.342C>T         p.Thr114Thr
# 1747  protein_coding            c.342C>T         p.Thr114Thr
# 1809  protein_coding            c.339A>G         p.Trp113Trp
# 1811  protein_coding            c.342C>T         p.Thr114Thr
# 1901  protein_coding            c.342C>T         p.Thr114Thr
# 1993  protein_coding             c.43T>C          p.Leu15Leu
# 1995  protein_coding            c.342C>T         p.Thr114Thr
# 2030  protein_coding            c.312T>C         p.Tyr104Tyr
# 2032  protein_coding            c.342C>T         p.Thr114Thr
# 2096  protein_coding            c.342C>T         p.Thr114Thr
# 2189  protein_coding            c.342C>T         p.Thr114Thr
# 2229  protein_coding            c.342C>T         p.Thr114Thr
# 2378  protein_coding            c.342C>T         p.Thr114Thr
# 2423  protein_coding            c.342C>T         p.Thr114Thr
# 2495  protein_coding            c.252G>A          p.Leu84Leu
# 2533  protein_coding            c.342C>T         p.Thr114Thr
# 2572  protein_coding            c.342C>T         p.Thr114Thr
# 2607  protein_coding            c.252G>A          p.Leu84Leu
# 2608  protein_coding            c.262G>A          p.Val88Ile
# 2663  protein_coding            c.342C>T         p.Thr114Thr

# %%
# Filtering the dataset for synonymous and non-synonymous mutations in the ND3 gene
nd3_chinese_synonymous_unique = nd3_chinese_unique[nd3_chinese_unique['gene_variant'] == 'synonymous_variant']
nd3_chinese_missense_unique = nd3_chinese_unique[nd3_chinese_unique['gene_variant'] == 'missense_variant']
nd3_armenian_synonymous_unique = nd3_armenian_unique[nd3_armenian_unique['gene_variant'] == 'synonymous_variant']
nd3_armenian_missense_unique = nd3_armenian_unique[nd3_armenian_unique['gene_variant'] == 'missense_variant']

# Counting the number of synonymous (dS) and non-synonymous (dN) mutations in each population
chinese_dS_unique = nd3_chinese_synonymous_unique.shape[0]
chinese_dN_unique = nd3_chinese_missense_unique.shape[0]
armenian_dS_unique = nd3_armenian_synonymous_unique.shape[0]
armenian_dN_unique = nd3_armenian_missense_unique.shape[0]

# Calculating the dN/dS ratio for each population
# Avoid division by zero by adding a small number (epsilon) to the denominator
epsilon = 1e-6
chinese_dN_dS_ratio_unique = chinese_dN_unique / (chinese_dS_unique + epsilon)
armenian_dN_dS_ratio_unique = armenian_dN_unique / (armenian_dS_unique + epsilon)

(chinese_dN_dS_ratio_unique, armenian_dN_dS_ratio_unique, chinese_dN_unique, chinese_dS_unique, armenian_dN_unique, armenian_dS_unique)
# Out:
# (0.037037035665294975, 0.0, 1, 27, 0, 5)

# %%
# Filtering the dataset for mutations in the ND3 gene for both Chinese and Armenian populations
# Analyzing ND3 mutations
# 1. Number of unique mutations in ND3 for each population
# 2. Distribution of ND3 mutations across loci
# 3. Types of ND3 gene variants

# Creating subplots for visualization
fig, axes = plt.subplots(3, 2, figsize=(18, 12))

# Plot 1: Distribution of ND3 mutations across loci for Chinese patients
sns.countplot(y="mutation_nucleotide", data=nd3_chinese, order=nd3_chinese['mutation_nucleotide'].value_counts().index, ax=axes[0, 0])
axes[0, 0].set_title('General Distribution of ND3 Mutations Across mutation_nucleotide in Chinese Patients')
axes[0, 0].set_xlabel('Count of Mutations')
axes[0, 0].set_ylabel('mutation_nucleotide')

# Plot 2: Distribution of ND3 mutations across loci for Armenian patients
sns.countplot(y="mutation_nucleotide", data=nd3_armenian, order=nd3_armenian['mutation_nucleotide'].value_counts().index, ax=axes[0, 1])
axes[0, 1].set_title('General Distribution of ND3 Mutations Across mutation_nucleotide in Armenian Patients')
axes[0, 1].set_xlabel('Count of Mutations')
axes[0, 1].set_ylabel('mutation_nucleotide')

# Plot 3: Types of ND3 gene variants in Chinese patients
sns.countplot(y="mutation_nucleotide", data=common_nd3_chinese, order= common_nd3_chinese['mutation_nucleotide'].value_counts().index, ax=axes[1, 0])
axes[1, 0].set_title('Common Distribution of ND3 Mutations Across mutation_nucleotide in Chinese Patients')
axes[1, 0].set_xlabel('Count')
axes[1, 0].set_ylabel('mutation_nucleotide')

# Plot 4: Types of ND3 gene variants in Armenian patients
sns.countplot(y="mutation_nucleotide", data=common_nd3_armenian, order=common_nd3_armenian['mutation_nucleotide'].value_counts().index, ax=axes[1, 1])
axes[1, 1].set_title('Types of ND3 Gene Variants in Armenian Patients')
axes[1, 1].set_xlabel('Common Distribution of ND3 Mutations Across mutation_nucleotide in Armenian Patients')
axes[1, 1].set_ylabel('mutation_nucleotide')

# Plot 5: Types of ND3 gene variants in Chinese patients
sns.countplot(y="mutation_nucleotide", data=nd3_chinese_unique, order= nd3_chinese_unique['mutation_nucleotide'].value_counts().index, ax=axes[2, 0])
axes[2, 0].set_title('Uniqu Distribution of ND3 Mutations Across mutation_nucleotide in Chinese Patients')
axes[2, 0].set_xlabel('Count')
axes[2, 0].set_ylabel('mutation_nucleotide')

# Plot 6: Types of ND3 gene variants in Armenian patients
sns.countplot(y="mutation_nucleotide", data=nd3_armenian_unique, order=nd3_armenian_unique['mutation_nucleotide'].value_counts().index, ax=axes[2, 1])
axes[2, 1].set_title('Types of ND3 Gene Variants in Armenian Patients')
axes[2, 1].set_xlabel('Unique Distribution of ND3 Mutations Across mutation_nucleotide in Armenian Patients')
axes[2, 1].set_ylabel('mutation_nucleotide')

plt.tight_layout()
plt.show()

(unique_nd3_mutations_chinese, unique_nd3_mutations_armenian)
# Out:
# (10, 7)

# %%
# Filtering the dataset for mutations in the ND3 gene for both Chinese and Armenian populations
# Analyzing ND3 mutations
# 1. Number of unique mutations in ND3 for each population
# 2. Distribution of ND3 mutations across loci
# 3. Types of ND3 gene variants

# Creating subplots for visualization
fig, axes = plt.subplots(3, 2, figsize=(18, 12))

# Plot 1: Distribution of ND3 mutations across loci for Chinese patients
hue_column = 'gene_variant'
color_palette = {"synonymous_variant": "darkblue", "missense_variant": "orange", 'upstream_gene_variant': "darkgreen"}
sns.countplot(y="mutation_nucleotide", data=nd3_chinese, order=nd3_chinese['mutation_nucleotide'].value_counts().index, hue=hue_column, palette=color_palette, ax=axes[0, 0])
axes[0, 0].set_title('General Distribution of ND3 Mutations Across mutation_nucleotide in Chinese Patients')
axes[0, 0].set_xlabel('Count of Mutations')
axes[0, 0].set_ylabel('mutation_nucleotide')

# Plot 2: Distribution of ND3 mutations across loci for Armenian patients
sns.countplot(y="mutation_nucleotide", data=nd3_armenian, order=nd3_armenian['mutation_nucleotide'].value_counts().index, hue=hue_column, palette=color_palette, ax=axes[0, 1])
axes[0, 1].set_title('General Distribution of ND3 Mutations Across mutation_nucleotide in Armenian Patients')
axes[0, 1].set_xlabel('Count of Mutations')
axes[0, 1].set_ylabel('mutation_nucleotide')

# Plot 3: Types of ND3 gene variants in Chinese patients
sns.countplot(y="mutation_nucleotide", data=common_nd3_chinese, order= common_nd3_chinese['mutation_nucleotide'].value_counts().index, hue=hue_column, palette=color_palette, ax=axes[1, 0])
axes[1, 0].set_title('Common Distribution of ND3 Mutations Across mutation_nucleotide in Chinese Patients')
axes[1, 0].set_xlabel('Count')
axes[1, 0].set_ylabel('mutation_nucleotide')

# Plot 4: Types of ND3 gene variants in Armenian patients
sns.countplot(y="mutation_nucleotide", data=common_nd3_armenian, order=common_nd3_armenian['mutation_nucleotide'].value_counts().index, hue=hue_column, palette=color_palette, ax=axes[1, 1])
axes[1, 1].set_title('Common Distribution of ND3 Mutations Across mutation_nucleotide in Armenian Patients')
axes[1, 1].set_xlabel('Count')
axes[1, 1].set_ylabel('mutation_nucleotide')

# Plot 5: Types of ND3 gene variants in Chinese patients
sns.countplot(y="mutation_nucleotide", data=nd3_chinese_unique, order= nd3_chinese_unique['mutation_nucleotide'].value_counts().index, hue=hue_column, palette=color_palette, ax=axes[2, 0])
axes[2, 0].set_title('Unique Distribution of ND3 Mutations Across mutation_nucleotide in Chinese Patients')
axes[2, 0].set_xlabel('Count')
axes[2, 0].set_ylabel('mutation_nucleotide')

# Plot 6: Types of ND3 gene variants in Armenian patients
sns.countplot(y="mutation_nucleotide", data=nd3_armenian_unique, order=nd3_armenian_unique['mutation_nucleotide'].value_counts().index, hue=hue_column, palette=color_palette, ax=axes[2, 1])
axes[2, 1].set_title('Unique Distribution of ND3 Mutations Across mutation_nucleotide in Armenian Patients')
axes[2, 1].set_xlabel('Count')
axes[2, 1].set_ylabel('mutation_nucleotide')

plt.tight_layout()
plt.show()

(unique_nd3_mutations_chinese, unique_nd3_mutations_armenian)
# Out:
# (10, 7)

# %%
# Out:
# /tmp/ipykernel_98428/203366806.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   common_nd3_chinese['Type'] = 'Common'
# /tmp/ipykernel_98428/203366806.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nd3_chinese_unique['Type'] = 'Unique'
# /tmp/ipykernel_98428/203366806.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   common_nd3_armenian['Type'] = 'Common'
# /tmp/ipykernel_98428/203366806.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nd3_armenian_unique['Type'] = 'Unique'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[65], line 23
#      20 fig, axes = plt.subplots(1, 2, figsize=(18, 6))
#      22 # Plot for Chinese patients
# ---> 23 sns.countplot(y="mutation_nucleotide", hue="gene_variant", style=nd3_chinese_combined["Type"], data=nd3_chinese_combined, ax=axes[0])
#      24 axes[0].set_title('ND3 Mutations in Chinese Patients')
#      25 axes[0].set_xlabel('Count of Mutations')
#
# File ~/.apps/conda/lib/python3.10/site-packages/seaborn/categorical.py:2955, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2952 if ax is None:
#    2953     ax = plt.gca()
# -> 2955 plotter.plot(ax, kwargs)
#    2956 return ax
#
# File ~/.apps/conda/lib/python3.10/site-packages/seaborn/categorical.py:1586, in _BarPlotter.plot(self, ax, bar_kws)
#    1584 def plot(self, ax, bar_kws):
#    1585     """Make the plot."""
# -> 1586     self.draw_bars(ax, bar_kws)
#    1587     self.annotate_axes(ax)
#    1588     if self.orient == "h":
#
# File ~/.apps/conda/lib/python3.10/site-packages/seaborn/categorical.py:1569, in _BarPlotter.draw_bars(self, ax, kws)
#    1565 for j, hue_level in enumerate(self.hue_names):
#    1566
#    1567     # Draw the bars
#    1568     offpos = barpos + self.hue_offsets[j]
# -> 1569     barfunc(offpos, self.statistic[:, j], self.nested_width,
#    1570             color=self.colors[j], align="center",
#    1571             label=hue_level, **kws)
#    1573     # Draw the confidence intervals
#    1574     if self.confint.size:
#
# File ~/.apps/conda/lib/python3.10/site-packages/matplotlib/axes/_axes.py:2641, in Axes.barh(self, y, width, height, left, align, data, **kwargs)
#    2531 r"""
#    2532 Make a horizontal bar plot.
#    2533
#    (...)
#    2638 :doc:`/gallery/lines_bars_and_markers/horizontal_barchart_distribution`.
#    2639 """
#    2640 kwargs.setdefault('orientation', 'horizontal')
# -> 2641 patches = self.bar(x=left, height=height, width=width, bottom=y,
#    2642                    align=align, data=data, **kwargs)
#    2643 return patches
#
# File ~/.apps/conda/lib/python3.10/site-packages/matplotlib/__init__.py:1446, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1443 @functools.wraps(func)
#    1444 def inner(ax, *args, data=None, **kwargs):
#    1445     if data is None:
# -> 1446         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448     bound = new_sig.bind(ax, *args, **kwargs)
#    1449     auto_label = (bound.arguments.get(label_namer)
#    1450                   or bound.kwargs.get(label_namer))
#
# File ~/.apps/conda/lib/python3.10/site-packages/matplotlib/axes/_axes.py:2480, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2471 for l, b, w, h, c, e, lw, htch, lbl in args:
#    2472     r = mpatches.Rectangle(
#    2473         xy=(l, b), width=w, height=h,
#    2474         facecolor=c,
#    (...)
#    2478         hatch=htch,
#    2479         )
# -> 2480     r._internal_update(kwargs)
#    2481     r.get_path()._interpolation_steps = 100
#    2482     if orientation == 'vertical':
#
# File ~/.apps/conda/lib/python3.10/site-packages/matplotlib/artist.py:1223, in Artist._internal_update(self, kwargs)
#    1216 def _internal_update(self, kwargs):
#    1217     """
#    1218     Update artist properties without prenormalizing them, but generating
#    1219     errors as if calling `set`.
#    1220
#    1221     The lack of prenormalization is to maintain backcompatibility.
#    1222     """
# -> 1223     return self._update_props(
#    1224         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1225         "{prop_name!r}")
#
# File ~/.apps/conda/lib/python3.10/site-packages/matplotlib/artist.py:1197, in Artist._update_props(self, props, errfmt)
#    1195             func = getattr(self, f"set_{k}", None)
#    1196             if not callable(func):
# -> 1197                 raise AttributeError(
#    1198                     errfmt.format(cls=type(self), prop_name=k))
#    1199             ret.append(func(v))
#    1200 if ret:
#
# AttributeError: Rectangle.set() got an unexpected keyword argument 'style'
